# %%
# !pip install numpy pandas scikit-learn seaborn jupyter
# Out:
# Collecting numpy
#   Using cached numpy-2.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: jupyter in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: notebook in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter) (4.2.5)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.7/163.7 kB 2.1 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six>=1.5 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-console->jupyter) (3.0.48)
# Requirement already satisfied: pygments in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: webencodings in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.0)
# Requirement already satisfied: certifi in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.5)
# Requirement already satisfied: idna in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/lillian/Documents/workme/me/mlzoomcamp/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20240906)
# Using cached numpy-2.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 21.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, seaborn
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.2 numpy-2.1.1 pandas-2.2.3 pillow-10.4.0 pyparsing-3.1.4 pytz-2024.2 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 threadpoolctl-3.5.0 tzdata-2024.2

# %% [markdown]
# Set up the environment
# You need to install Python, NumPy, Pandas, Matplotlib and Seaborn. For that, you can use the instructions from 06-environment.md.
#
# Q1. Pandas version
# What's the version of Pandas that you installed?
#
# You can get the version information using the __version__ field:

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# Getting the data
# For this homework, we'll use the Laptops Price dataset. Download it from here.
#
# You can do it with wget:
#
# wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Or just open it with your browser and click "Save as...".
#
# Now read it with Pandas.

# %%
df = pd.read_csv("data/laptops.csv")

# %% [markdown]
# Q2. Records count
# How many records are in the dataset?
#
# 12
# 1000
# 2160
# 12160

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %% [markdown]
# Q3. Laptop brands
# How many laptop brands are presented in the dataset?
#
# 12
# 27
# 28
# 2160

# %%
print(df['Brand'].unique())
df['Brand'].unique().size
# Out:
# ['Asus' 'Alurin' 'MSI' 'HP' 'Lenovo' 'Medion' 'Acer' 'Apple' 'Razer'
#  'Gigabyte' 'Dell' 'LG' 'Samsung' 'PcCom' 'Microsoft' 'Primux' 'Prixton'
#  'Dynabook Toshiba' 'Thomson' 'Denver' 'Deep Gaming' 'Vant' 'Innjoo'
#  'Jetwing' 'Millenium' 'Realme' 'Toshiba']
# 27

# %% [markdown]
# Q4. Missing values
# How many columns in the dataset have missing values?
#
# 0
# 1
# 2
# 3

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %% [markdown]
# Q5. Maximum final price
# What's the maximum final price of Dell notebooks in the dataset?
#
# 869
# 3691
# 3849
# 3936

# %%
dell_notebooks = df[df['Brand'] == 'Dell']
dell_notebooks['Final Price'].max()
# Out:
# np.float64(3936.0)

# %% [markdown]
# Q6. Median value of Screen
# Find the median value of Screen column in the dataset.
# Next, calculate the most frequent value of the same Screen column.
# Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
# Now, calculate the median value of Screen once again.
# Has it changed?
#
# Hint: refer to existing mode and median functions to complete the task.
#
# Yes
# No

# %%
median_screen = df['Screen'].median()
print(median_screen)

most_frequent_screen = df['Screen'].mode().iloc[0]
print(most_frequent_screen)

df['Screen'].fillna(most_frequent_screen, inplace=True)
new_median_screen = df['Screen'].median()

if median_screen == new_median_screen:
    print("The median value has not changed.")
else:
    print("The median value has changed.")
# Out:
# 15.6
# 15.6
# The median value has not changed.
# /tmp/ipykernel_30617/2406970125.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Screen'].fillna(most_frequent_screen, inplace=True)

# %% [markdown]
# Q7. Sum of weights
# Select all the "Innjoo" laptops from the dataset.
# Select only columns RAM, Storage, Screen.
# Get the underlying NumPy array. Let's call it X.
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# Compute the inverse of XTX.
# Create an array y with values [1100, 1300, 800, 900, 1000, 1100].
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# What's the sum of all the elements of the result?
# Note: You just implemented linear regression. We'll talk about it in the next lesson.
#
# 0.43
# 45.29
# 45.58
# 91.30

# %%
innjoo_laptops = df[df['Brand'] == 'Innjoo']
X = innjoo_laptops.loc[:, ['RAM', 'Storage', 'Screen']].values
XTX = X.T @ X
import numpy as np
XTX_inv = np.linalg.inv(XTX)
y = np.array([1100, 1300, 800, 900, 1000, 1100])
w = XTX_inv @ X.T @ y
sum_w = np.sum(w)
print(sum_w)
# Out:
# 91.2998806299555
